# %%
from IPython.display import Image, display

# Display image
display(Image(filename='Test3.png'))

# %%
from IPython.display import Image, display

# Display image
display(Image(filename='Test4.png'))

# %%
# From the above output, we can say that the Gradio interface has been successfully launched 
# for the GPT-2 Next Word Prediction task. The user has entered the partial sentence:
# "She opened the door and began to"
#
# Based on this input, the GPT-2 model predicts the most probable next words along with 
# their respective probabilities, as shown above.
#
# Among the predictions, the model considers “walk” to be the most likely continuation 
# of the sentence, followed by other plausible actions like “sing,” “climb,” and “speak.”
